# %% [markdown]
# # Working with Time
#
# * One of the most powerful features of Pandas is its time series functionality
# * Dates and time are a Python and Pandas data type (like integers and strings)
# * By using the `datetime` data types you can do advanced, time-centric analysis
# * One thing to remember about computers is they are *very* specific
#     * *Time stamps* - a specific moment in time (July 4th, 2017 at 7:52am and 34 seconds)
#     * *Time intervals* - a length of time with start and end points (The year 2017)
#     * *Time duration* - a specific length of time (a year, a month, a day)
#
#
# * Python has data structures for working with time as part of the standard library

# %%
# Datetime in pure Python
import datetime

date = datetime.datetime(year=2017, month=6, day=13)
date
# Out:
# datetime.datetime(2017, 6, 13, 0, 0)

# %%
# A more specific datetime in pure Python
import datetime

date = datetime.datetime(year=2017, month=6, day=13, hour=4, minute=45, second=3, microsecond=13)
date
# Out:
# datetime.datetime(2017, 6, 13, 4, 45, 3, 13)

# %%
type(date)
# Out:
# datetime.datetime

# %%
# what is that date's month?
date.month
# Out:
# 6

# %%
# what is that date's day?
date.day
# Out:
# 13

# %% [markdown]
# * Python comes with a handle utility for parsing date strings into `datetime` objects called `dateutil.parser`

# %%
# import the parser function from the datautil library to parse human date strings
from dateutil import parser
date = parser.parse("4th of July, 2017")
date
# Out:
# datetime.datetime(2017, 7, 4, 0, 0)

# %%
# get the month
date.month
# Out:
# 7

# %% [markdown]
# ## Exercise
#
# Try some different date strings, see how smart Python can be.

# %%
my_date = parser.parse("23Oct2019")
print(my_date)
my_date.day
# Out:
# 2019-10-23 00:00:00
# 23

# %%
stringy = "January 1st 2900 at 3:15pm 45seconds"
parser.parse(stringy)
# Out:
# datetime.datetime(2900, 1, 1, 15, 15, 45)

# %% [markdown]
# ## Formatting Dates and Times

# %% [markdown]
# * You can use [*string format codes*](https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior) for printing dates and time in different formats (especially useful for making human readable dates)
# * Pass a format string to the `strftime()` method to print out a pretty date #string format time

# %%
# Get the weekday 
date.strftime("%A")
# Out:
# 'Tuesday'

# %%
date.strftime("%B")
# Out:
# 'July'

# %%
date.strftime("%A, %B %d %f")
# Out:
# 'Tuesday, July 04 000000'

# %%
date.strftime("The ear of ar ord %Y")
# Out:
# 'The ear of ar ord 2017'

# %%
## Try some of the different string format codes and see what happens
date.strftime("%P")
# Out:
# 'am'

# %%
import locale

# %%
locale.getlocale()
# Out:
# ('en_US', 'UTF-8')

# %%
## Try combining a few of them together with punctuation too
date.strftime("%Y-%m-%d")
# Out:
# '2017-07-04'

# %% [markdown]
# ## Working with time in Pandas
#
# * Just like how Pandas has its own datatypes for numbers, Pandas has its own dates and times (to support more granularity)
# * If you have a lot of dates, it is often useful to use the Pandas functions over the native Python functions
# * Pandas is most powerful when you index by time using the `DatetimeIndex`

# %%
import pandas as pd

# %%
# Create a Series with a DateTime index
index = pd.DatetimeIndex(['2014-03-04', '2014-08-04',
                          '2015-04-04', '2015-09-04',
                          '2016-01-01', '2016-02-16'])
data = pd.Series([10, 13, 24, 34, 34, 25], index=index)
data
# Out:
# 2014-03-04    10
# 2014-08-04    13
# 2015-04-04    24
# 2015-09-04    34
# 2016-01-01    34
# 2016-02-16    25
# dtype: int64

# %% [markdown]
# * Now that the index is made of DateTimes we can index using date strings
# * Note, this only works on strings

# %%
# grab the value for a specific day
data["2015-04-04"]
# Out:
# 24

# %%
# grab a slice between two dates
data['2014-08-01':'2016-01']
# Out:
# 2014-08-04    13
# 2015-04-04    24
# 2015-09-04    34
# 2016-01-01    34
# dtype: int64

# %%
# give me everything from 2015
data['2015']
# Out:
# 2015-04-04    24
# 2015-09-04    34
# dtype: int64

# %% [markdown]
# * Pandas has some functions to make parsing dates easy too

# %%
# use the to_datetime function instead of the parser function
date = pd.to_datetime("4th of July, 2017")
date
# Out:
# Timestamp('2017-07-04 00:00:00')

# %%
# use string format codes to get the weekday
date.strftime("%A")
# Out:
# 'Tuesday'

# %%
# give me today's date
today = pd.to_datetime("today")
today
# Out:
# Timestamp('2019-10-23 15:28:55.089899')

# %% [markdown]
# * That is the day, but also the exact time...
# * Timestamps must always be a specific moment

# %% [markdown]
# ## Working with Time on Real Data
# * Let's look at the [311 data for the city of Pittsburgh](https://data.wprdc.org/dataset/311-data) from the WPRDC
# * Did you know, you can give the URL directly to Pandas!

# %%
# load the 311 data directly from the WPRDC
pgh_311_data = pd.read_csv("https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4")
pgh_311_data.head()
# Out:
#    REQUEST_ID           CREATED_ON                REQUEST_TYPE REQUEST_ORIGIN  \
# 0    203364.0  2017-12-15T14:53:00  Street Obstruction/Closure    Call Center
# 1    200800.0  2017-11-29T09:54:00                    Graffiti  Control Panel
# 2    201310.0  2017-12-01T13:23:00                      Litter    Call Center
# 3    200171.0  2017-11-22T14:54:00            Water Main Break    Call Center
# 4    193043.0  2017-10-12T12:46:00                  Guide Rail    Call Center
#
#    STATUS                            DEPARTMENT       NEIGHBORHOOD  \
# 0       1                        DOMI - Permits  Central Northside
# 1       1                    Police - Zones 1-6   South Side Flats
# 2       1              DPW - Street Maintenance          Troy Hill
# 3       0  Pittsburgh Water and Sewer Authority         Banksville
# 4       1           DPW - Construction Division         East Hills
#
#    COUNCIL_DISTRICT  WARD         TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# 0               1.0  22.0  4.200322e+10                    1.0          22.0
# 1               3.0  16.0  4.200316e+10                    3.0          16.0
# 2               1.0  24.0  4.200324e+10                    1.0          24.0
# 3               2.0  20.0  4.200320e+10                    5.0          20.0
# 4               9.0  13.0  4.200313e+10                    2.0          13.0
#
#    POLICE_ZONE FIRE_ZONE          X          Y GEO_ACCURACY
# 0          1.0       1-7 -80.016716  40.454144        EXACT
# 1          3.0      4-24 -79.969952  40.429243  APPROXIMATE
# 2          1.0       1-2 -79.985859  40.459716        EXACT
# 3          6.0       4-9 -80.034210  40.406969        EXACT
# 4          5.0      3-19 -79.876582  40.451226        EXACT

# %%
# Inspect the dataframe and Pandas automatic data type detection
pgh_311_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376060 entries, 0 to 376059
# Data columns (total 17 columns):
# REQUEST_ID               376059 non-null float64
# CREATED_ON               376060 non-null object
# REQUEST_TYPE             376060 non-null object
# REQUEST_ORIGIN           376060 non-null object
# STATUS                   376060 non-null int64
# DEPARTMENT               372410 non-null object
# NEIGHBORHOOD             351372 non-null object
# COUNCIL_DISTRICT         351934 non-null float64
# WARD                     351500 non-null float64
# TRACT                    352778 non-null float64
# PUBLIC_WORKS_DIVISION    351501 non-null float64
# PLI_DIVISION             351500 non-null float64
# POLICE_ZONE              351281 non-null float64
# FIRE_ZONE                351666 non-null object
# X                        355502 non-null float64
# Y                        355502 non-null float64
# GEO_ACCURACY             376060 non-null object
# dtypes: float64(9), int64(1), object(7)
# memory usage: 48.8+ MB

# %% [markdown]
# * Ok, now we have the data, but we need it to be indexed by date
# * **What column has the date information?**
# * **What format do you think that column is currently in?**
# * **What function might we use to convert that column into dates?**

# %%
pgh_311_data['CREATED_ON'].head()
# Out:
# 0    2017-12-15T14:53:00
# 1    2017-11-29T09:54:00
# 2    2017-12-01T13:23:00
# 3    2017-11-22T14:54:00
# 4    2017-10-12T12:46:00
# Name: CREATED_ON, dtype: object

# %%
# convert the "CREATED_ON" column to dates
pd.to_datetime(pgh_311_data['CREATED_ON']).head()
# Out:
# 0   2017-12-15 14:53:00
# 1   2017-11-29 09:54:00
# 2   2017-12-01 13:23:00
# 3   2017-11-22 14:54:00
# 4   2017-10-12 12:46:00
# Name: CREATED_ON, dtype: datetime64[ns]

# %% [markdown]
# * We can convert the "CREATED_ON" column to Pandas `datetime` objects
# * Now we have to set that to the dataframe's index

# %%
# set the index of pgh_311_data to be the parsed dates in the "CREATED_ON" column
pgh_311_data.index = pd.to_datetime(pgh_311_data['CREATED_ON'])
pgh_311_data.head()
# Out:
#                      REQUEST_ID           CREATED_ON  \
# CREATED_ON
# 2017-12-15 14:53:00    203364.0  2017-12-15T14:53:00
# 2017-11-29 09:54:00    200800.0  2017-11-29T09:54:00
# 2017-12-01 13:23:00    201310.0  2017-12-01T13:23:00
# 2017-11-22 14:54:00    200171.0  2017-11-22T14:54:00
# 2017-10-12 12:46:00    193043.0  2017-10-12T12:46:00
#
#                                    REQUEST_TYPE REQUEST_ORIGIN  STATUS  \
# CREATED_ON
# 2017-12-15 14:53:00  Street Obstruction/Closure    Call Center       1
# 2017-11-29 09:54:00                    Graffiti  Control Panel       1
# 2017-12-01 13:23:00                      Litter    Call Center       1
# 2017-11-22 14:54:00            Water Main Break    Call Center       0
# 2017-10-12 12:46:00                  Guide Rail    Call Center       1
#
#                                                DEPARTMENT       NEIGHBORHOOD  \
# CREATED_ON
# 2017-12-15 14:53:00                        DOMI - Permits  Central Northside
# 2017-11-29 09:54:00                    Police - Zones 1-6   South Side Flats
# 2017-12-01 13:23:00              DPW - Street Maintenance          Troy Hill
# 2017-11-22 14:54:00  Pittsburgh Water and Sewer Authority         Banksville
# 2017-10-12 12:46:00           DPW - Construction Division         East Hills
#
#                      COUNCIL_DISTRICT  WARD         TRACT  \
# CREATED_ON
# 2017-12-15 14:53:00               1.0  22.0  4.200322e+10
# 2017-11-29 09:54:00               3.0  16.0  4.200316e+10
# 2017-12-01 13:23:00               1.0  24.0  4.200324e+10
# 2017-11-22 14:54:00               2.0  20.0  4.200320e+10
# 2017-10-12 12:46:00               9.0  13.0  4.200313e+10
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# CREATED_ON
# 2017-12-15 14:53:00                    1.0          22.0          1.0
# 2017-11-29 09:54:00                    3.0          16.0          3.0
# 2017-12-01 13:23:00                    1.0          24.0          1.0
# 2017-11-22 14:54:00                    5.0          20.0          6.0
# 2017-10-12 12:46:00                    2.0          13.0          5.0
#
#                     FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2017-12-15 14:53:00       1-7 -80.016716  40.454144        EXACT
# 2017-11-29 09:54:00      4-24 -79.969952  40.429243  APPROXIMATE
# 2017-12-01 13:23:00       1-2 -79.985859  40.459716        EXACT
# 2017-11-22 14:54:00       4-9 -80.034210  40.406969        EXACT
# 2017-10-12 12:46:00      3-19 -79.876582  40.451226        EXACT

# %% [markdown]
# * Do'h, now we have CREATED_ON twice, that isn't very tidy
# * We can also skip this extra conversion step entirely by specifying the index column and date parsing in `read_csv()` function call.

# %%
# load the 311 data directly from the WPRDC and parse dates directly
pgh_311_data = pd.read_csv("https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4",
                           index_col="CREATED_ON", 
                           parse_dates=True)
pgh_311_data.head()
# Out:
#                      REQUEST_ID                REQUEST_TYPE REQUEST_ORIGIN  \
# CREATED_ON
# 2017-12-15 14:53:00    203364.0  Street Obstruction/Closure    Call Center
# 2017-11-29 09:54:00    200800.0                    Graffiti  Control Panel
# 2017-12-01 13:23:00    201310.0                      Litter    Call Center
# 2017-11-22 14:54:00    200171.0            Water Main Break    Call Center
# 2017-10-12 12:46:00    193043.0                  Guide Rail    Call Center
#
#                      STATUS                            DEPARTMENT  \
# CREATED_ON
# 2017-12-15 14:53:00       1                        DOMI - Permits
# 2017-11-29 09:54:00       1                    Police - Zones 1-6
# 2017-12-01 13:23:00       1              DPW - Street Maintenance
# 2017-11-22 14:54:00       0  Pittsburgh Water and Sewer Authority
# 2017-10-12 12:46:00       1           DPW - Construction Division
#
#                           NEIGHBORHOOD  COUNCIL_DISTRICT  WARD         TRACT  \
# CREATED_ON
# 2017-12-15 14:53:00  Central Northside               1.0  22.0  4.200322e+10
# 2017-11-29 09:54:00   South Side Flats               3.0  16.0  4.200316e+10
# 2017-12-01 13:23:00          Troy Hill               1.0  24.0  4.200324e+10
# 2017-11-22 14:54:00         Banksville               2.0  20.0  4.200320e+10
# 2017-10-12 12:46:00         East Hills               9.0  13.0  4.200313e+10
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# CREATED_ON
# 2017-12-15 14:53:00                    1.0          22.0          1.0
# 2017-11-29 09:54:00                    3.0          16.0          3.0
# 2017-12-01 13:23:00                    1.0          24.0          1.0
# 2017-11-22 14:54:00                    5.0          20.0          6.0
# 2017-10-12 12:46:00                    2.0          13.0          5.0
#
#                     FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2017-12-15 14:53:00       1-7 -80.016716  40.454144        EXACT
# 2017-11-29 09:54:00      4-24 -79.969952  40.429243  APPROXIMATE
# 2017-12-01 13:23:00       1-2 -79.985859  40.459716        EXACT
# 2017-11-22 14:54:00       4-9 -80.034210  40.406969        EXACT
# 2017-10-12 12:46:00      3-19 -79.876582  40.451226        EXACT

# %%
pgh_311_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 376060 entries, 2017-12-15 14:53:00 to 2019-10-23 15:35:00
# Data columns (total 16 columns):
# REQUEST_ID               376059 non-null float64
# REQUEST_TYPE             376060 non-null object
# REQUEST_ORIGIN           376060 non-null object
# STATUS                   376060 non-null int64
# DEPARTMENT               372410 non-null object
# NEIGHBORHOOD             351372 non-null object
# COUNCIL_DISTRICT         351934 non-null float64
# WARD                     351500 non-null float64
# TRACT                    352778 non-null float64
# PUBLIC_WORKS_DIVISION    351501 non-null float64
# PLI_DIVISION             351500 non-null float64
# POLICE_ZONE              351281 non-null float64
# FIRE_ZONE                351666 non-null object
# X                        355502 non-null float64
# Y                        355502 non-null float64
# GEO_ACCURACY             376060 non-null object
# dtypes: float64(9), int64(1), object(6)
# memory usage: 48.8+ MB

# %% [markdown]
# * Now that the dataframe has been indexed by time we can select 311 complains by time

# %%
# Select 311 complaints on January 1st, 2016
pgh_311_data['2016-01-01']
# Out:
#                      REQUEST_ID                          REQUEST_TYPE  \
# CREATED_ON
# 2016-01-01 20:46:00     39146.0                   No Parking Variance
# 2016-01-01 23:32:00     39154.0                              Speeding
# 2016-01-01 18:51:00     39137.0    Sidewalk, Lack of Snow/Ice Removal
# 2016-01-01 02:22:00     39133.0                             Curb Cuts
# 2016-01-01 20:42:00     39145.0              Sidewalk (City Property)
# 2016-01-01 19:22:00     39139.0           Court, Basketball or Tennis
# 2016-01-01 20:08:00     39142.0                 Collapsed Catch Basin
# 2016-01-01 20:30:00     39143.0                 Collapsed Catch Basin
# 2016-01-01 18:45:00     39136.0    Sidewalk, Lack of Snow/Ice Removal
# 2016-01-01 19:03:00     39138.0           Court, Basketball or Tennis
# 2016-01-01 12:21:00     39135.0          Excessive Noise/Disturbances
# 2016-01-01 20:04:00     39141.0                 Collapsed Catch Basin
# 2016-01-01 21:23:00     39153.0  Abandoned Vehicle (parked on street)
# 2016-01-01 19:31:00     39140.0                Paving Concern/Problem
# 2016-01-01 01:14:00     39132.0                              Potholes
# 2016-01-01 21:14:00     39152.0                        Water Pressure
# 2016-01-01 21:07:00     39150.0                         Gang Activity
# 2016-01-01 20:42:00     39144.0                       Illegal Parking
# 2016-01-01 21:09:00     39151.0               Other (please describe)
# 2016-01-01 20:51:00     39147.0                         Towed Vehicle
# 2016-01-01 20:59:00     39149.0                               Traffic
#
#                      REQUEST_ORIGIN  STATUS  \
# CREATED_ON
# 2016-01-01 20:46:00         Website       1
# 2016-01-01 23:32:00  Report2Gov iOS       1
# 2016-01-01 18:51:00         Website       3
# 2016-01-01 02:22:00         Website       1
# 2016-01-01 20:42:00         Website       3
# 2016-01-01 19:22:00         Website       1
# 2016-01-01 20:08:00         Website       1
# 2016-01-01 20:30:00         Website       1
# 2016-01-01 18:45:00         Website       1
# 2016-01-01 19:03:00         Website       1
# 2016-01-01 12:21:00         Website       1
# 2016-01-01 20:04:00         Website       1
# 2016-01-01 21:23:00         Website       1
# 2016-01-01 19:31:00         Website       1
# 2016-01-01 01:14:00         Website       1
# 2016-01-01 21:14:00         Website       1
# 2016-01-01 21:07:00         Website       1
# 2016-01-01 20:42:00         Website       1
# 2016-01-01 21:09:00         Website       1
# 2016-01-01 20:51:00         Website       1
# 2016-01-01 20:59:00         Website       1
#
#                                                DEPARTMENT  \
# CREATED_ON
# 2016-01-01 20:46:00                        DOMI - Permits
# 2016-01-01 23:32:00                    Police - Zones 1-6
# 2016-01-01 18:51:00                        DOMI - Permits
# 2016-01-01 02:22:00                        DOMI - Permits
# 2016-01-01 20:42:00                        DOMI - Streets
# 2016-01-01 19:22:00                DPW - Park Maintenance
# 2016-01-01 20:08:00  Pittsburgh Water and Sewer Authority
# 2016-01-01 20:30:00  Pittsburgh Water and Sewer Authority
# 2016-01-01 18:45:00                        DOMI - Permits
# 2016-01-01 19:03:00                DPW - Park Maintenance
# 2016-01-01 12:21:00                    Police - Zones 1-6
# 2016-01-01 20:04:00  Pittsburgh Water and Sewer Authority
# 2016-01-01 21:23:00                          Police - AVU
# 2016-01-01 19:31:00                        DOMI - Asphalt
# 2016-01-01 01:14:00              DPW - Street Maintenance
# 2016-01-01 21:14:00  Pittsburgh Water and Sewer Authority
# 2016-01-01 21:07:00                    Police - Zones 1-6
# 2016-01-01 20:42:00                    Police - Zones 1-6
# 2016-01-01 21:09:00                 Animal Care & Control
# 2016-01-01 20:51:00                          Police - AVU
# 2016-01-01 20:59:00                    Police - Zones 1-6
#
#                                   NEIGHBORHOOD  COUNCIL_DISTRICT  WARD  \
# CREATED_ON
# 2016-01-01 20:46:00                        NaN               NaN   NaN
# 2016-01-01 23:32:00                 Banksville               2.0  20.0
# 2016-01-01 18:51:00            Crafton Heights               2.0  28.0
# 2016-01-01 02:22:00                  Beechview               4.0  19.0
# 2016-01-01 20:42:00                   Westwood               2.0  28.0
# 2016-01-01 19:22:00            Crafton Heights               2.0  28.0
# 2016-01-01 20:08:00            Crafton Heights               2.0  28.0
# 2016-01-01 20:30:00            Crafton Heights               2.0  28.0
# 2016-01-01 18:45:00            Crafton Heights               2.0  28.0
# 2016-01-01 19:03:00            Crafton Heights               2.0  28.0
# 2016-01-01 12:21:00                    Carrick               4.0  29.0
# 2016-01-01 20:04:00            Crafton Heights               2.0  28.0
# 2016-01-01 21:23:00              South Oakland               6.0   4.0
# 2016-01-01 19:31:00            Crafton Heights               2.0  28.0
# 2016-01-01 01:14:00           South Side Flats               3.0  17.0
# 2016-01-01 21:14:00  Central Business District               6.0   2.0
# 2016-01-01 21:07:00  Central Business District               6.0   2.0
# 2016-01-01 20:42:00          South Side Slopes               3.0  16.0
# 2016-01-01 21:09:00  Central Business District               6.0   2.0
# 2016-01-01 20:51:00                        NaN               NaN   NaN
# 2016-01-01 20:59:00                        NaN               NaN   NaN
#
#                             TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# CREATED_ON
# 2016-01-01 20:46:00           NaN                    NaN           NaN
# 2016-01-01 23:32:00  4.200320e+10                    5.0          20.0
# 2016-01-01 18:51:00  4.200328e+10                    5.0          28.0
# 2016-01-01 02:22:00  4.200319e+10                    5.0          19.0
# 2016-01-01 20:42:00  4.200356e+10                    5.0          28.0
# 2016-01-01 19:22:00  4.200328e+10                    5.0          28.0
# 2016-01-01 20:08:00  4.200328e+10                    5.0          28.0
# 2016-01-01 20:30:00  4.200328e+10                    5.0          28.0
# 2016-01-01 18:45:00  4.200328e+10                    5.0          28.0
# 2016-01-01 19:03:00  4.200328e+10                    5.0          28.0
# 2016-01-01 12:21:00  4.200329e+10                    3.0          29.0
# 2016-01-01 20:04:00  4.200328e+10                    5.0          28.0
# 2016-01-01 21:23:00  4.200304e+10                    3.0           4.0
# 2016-01-01 19:31:00  4.200328e+10                    5.0          28.0
# 2016-01-01 01:14:00  4.200317e+10                    3.0          17.0
# 2016-01-01 21:14:00  4.200302e+10                    6.0           2.0
# 2016-01-01 21:07:00  4.200302e+10                    6.0           2.0
# 2016-01-01 20:42:00  4.200316e+10                    3.0          16.0
# 2016-01-01 21:09:00  4.200302e+10                    6.0           2.0
# 2016-01-01 20:51:00           NaN                    NaN           NaN
# 2016-01-01 20:59:00           NaN                    NaN           NaN
#
#                      POLICE_ZONE FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2016-01-01 20:46:00          NaN       NaN   0.000000   0.000000        EXACT
# 2016-01-01 23:32:00          6.0       4-9 -80.043030  40.404907        EXACT
# 2016-01-01 18:51:00          6.0      1-18 -80.055911  40.439564        EXACT
# 2016-01-01 02:22:00          6.0      4-28 -80.021355  40.412577        EXACT
# 2016-01-01 20:42:00          6.0      1-18 -80.054233  40.431828        EXACT
# 2016-01-01 19:22:00          6.0      1-18 -80.055990  40.439711        EXACT
# 2016-01-01 20:08:00          6.0      1-18 -80.055873  40.439591        EXACT
# 2016-01-01 20:30:00          6.0      1-18 -80.055873  40.439591        EXACT
# 2016-01-01 18:45:00          6.0      1-18 -80.055965  40.439705        EXACT
# 2016-01-01 19:03:00          6.0      1-18 -80.055769  40.439332        EXACT
# 2016-01-01 12:21:00          3.0      4-15 -79.980253  40.388295  APPROXIMATE
# 2016-01-01 20:04:00          6.0      1-18 -80.055873  40.439591        EXACT
# 2016-01-01 21:23:00          4.0      2-10 -79.962630  40.435759  APPROXIMATE
# 2016-01-01 19:31:00          6.0      1-18 -80.055827  40.439602        EXACT
# 2016-01-01 01:14:00          3.0      4-24 -79.984121  40.430102        EXACT
# 2016-01-01 21:14:00          2.0       1-4 -79.997302  40.438702        EXACT
# 2016-01-01 21:07:00          2.0       1-4 -79.995701  40.439397  APPROXIMATE
# 2016-01-01 20:42:00          3.0      4-24 -79.970799  40.423129  APPROXIMATE
# 2016-01-01 21:09:00          2.0       1-4 -79.995805  40.439529  APPROXIMATE
# 2016-01-01 20:51:00          NaN       NaN   0.000000   0.000000        EXACT
# 2016-01-01 20:59:00          NaN       NaN   0.000000   0.000000        EXACT

# %%
# Select the times just around the new years celebration
pgh_311_data["2015-12-31 20:00:00":"2016-01-01 02:00:00"]
# Out:
#                      REQUEST_ID REQUEST_TYPE REQUEST_ORIGIN  STATUS  \
# CREATED_ON
# 2016-01-01 01:14:00     39132.0     Potholes        Website       1
#
#                                    DEPARTMENT      NEIGHBORHOOD  \
# CREATED_ON
# 2016-01-01 01:14:00  DPW - Street Maintenance  South Side Flats
#
#                      COUNCIL_DISTRICT  WARD         TRACT  \
# CREATED_ON
# 2016-01-01 01:14:00               3.0  17.0  4.200317e+10
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# CREATED_ON
# 2016-01-01 01:14:00                    3.0          17.0          3.0
#
#                     FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2016-01-01 01:14:00      4-24 -79.984121  40.430102        EXACT

# %% [markdown]
# * Someone clearly had a very rowdy new years

# %% [markdown]
# ## Exercise
#
# * Using the timeseries index selection, select the complaints made today
# * Next, try and write your code so it will work on any day you execute it
#     * *hint*: try the `pd.datetime('today')`
#     * *Another hint*: Remember the DateTime gives you the exact time
#     * *Yet another hint*: Datetime indexing only works with string representations

# %%
# Write your code here
pgh_311_data[]

# %%
pgh_311_data['2018-10-24'].head()
# Out:
#                      REQUEST_ID                          REQUEST_TYPE  \
# CREATED_ON
# 2018-10-24 06:48:00    297188.0         Construction Site Maintenance
# 2018-10-24 06:49:00    297189.0                       Illegal Parking
# 2018-10-24 07:34:00    297190.0                Paving Concern/Problem
# 2018-10-24 08:02:00    297191.0                              Potholes
# 2018-10-24 08:07:00    297192.0  Traffic or Pedestrian Signal, Repair
#
#                     REQUEST_ORIGIN  STATUS                         DEPARTMENT  \
# CREATED_ON
# 2018-10-24 06:48:00        Website       1  Permits, Licenses and Inspections
# 2018-10-24 06:49:00        Website       1                 Police - Zones 1-6
# 2018-10-24 07:34:00        Website       0                     DOMI - Asphalt
# 2018-10-24 08:02:00    Call Center       1           DPW - Street Maintenance
# 2018-10-24 08:07:00    Call Center       1                 DOMI - TrafficShop
#
#                             NEIGHBORHOOD  COUNCIL_DISTRICT  WARD  \
# CREATED_ON
# 2018-10-24 06:48:00             Garfield               9.0  11.0
# 2018-10-24 06:49:00  Lower Lawrenceville               7.0   6.0
# 2018-10-24 07:34:00            Beechview               4.0  19.0
# 2018-10-24 08:02:00          Morningside               7.0  10.0
# 2018-10-24 08:07:00        North Oakland               8.0   4.0
#
#                             TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# CREATED_ON
# 2018-10-24 06:48:00  4.200311e+10                    2.0          11.0
# 2018-10-24 06:49:00  4.200306e+10                    2.0           6.0
# 2018-10-24 07:34:00  4.200319e+10                    5.0          19.0
# 2018-10-24 08:02:00  4.200310e+10                    2.0          10.0
# 2018-10-24 08:07:00  4.200398e+10                    3.0           4.0
#
#                      POLICE_ZONE FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2018-10-24 06:48:00          5.0       3-8 -79.929339  40.467210  APPROXIMATE
# 2018-10-24 06:49:00          2.0       3-6 -79.961012  40.463392  APPROXIMATE
# 2018-10-24 07:34:00          6.0      4-28 -80.022900  40.411852        EXACT
# 2018-10-24 08:02:00          5.0       3-7 -79.925555  40.484595        EXACT
# 2018-10-24 08:07:00          4.0       2-7 -79.954810  40.444422        EXACT

# %%
# create a Pandas datetime for today
today = pd.to_datetime("today")
formatted_today_string = today.strftime("%Y-%m-%d")
print(today)
print(formatted_today_string)

# use Pandas date string indexing to retrieve all rows for this today's date
todays_311s = pgh_311_data[formatted_today_string]
todays_311s.head()
# Out:
# 2019-10-23 15:39:27.563218
# 2019-10-23
#                      REQUEST_ID                 REQUEST_TYPE  REQUEST_ORIGIN  \
# CREATED_ON
# 2019-10-23 05:48:00    392380.0        Street Light - Repair  Report2Gov iOS
# 2019-10-23 07:15:00    392381.0  Commercial Refuse/Dumpsters         Website
# 2019-10-23 07:33:00    392382.0              Fire Department     Call Center
# 2019-10-23 07:34:00    392383.0                  Dead Animal     Call Center
# 2019-10-23 07:35:00    392384.0        Replace/Repair a Sign     Call Center
#
#                      STATUS               DEPARTMENT           NEIGHBORHOOD  \
# CREATED_ON
# 2019-10-23 05:48:00       0  Allegheny City Electric  Central Lawrenceville
# 2019-10-23 07:15:00       3             DPW - Refuse       South Side Flats
# 2019-10-23 07:33:00       0              Fire Bureau              Allentown
# 2019-10-23 07:34:00       0    Animal Care & Control        Stanton Heights
# 2019-10-23 07:35:00       3       DOMI - TrafficShop    Squirrel Hill North
#
#                      COUNCIL_DISTRICT  WARD         TRACT  \
# CREATED_ON
# 2019-10-23 05:48:00               7.0   9.0  4.200309e+10
# 2019-10-23 07:15:00               3.0  17.0  4.200317e+10
# 2019-10-23 07:33:00               3.0  18.0  4.200318e+10
# 2019-10-23 07:34:00               9.0  10.0  4.200310e+10
# 2019-10-23 07:35:00               8.0  14.0  4.200314e+10
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# CREATED_ON
# 2019-10-23 05:48:00                    2.0           9.0          2.0
# 2019-10-23 07:15:00                    3.0          17.0          3.0
# 2019-10-23 07:33:00                    5.0          18.0          3.0
# 2019-10-23 07:34:00                    2.0          10.0          5.0
# 2019-10-23 07:35:00                    3.0          14.0          4.0
#
#                     FIRE_ZONE          X          Y GEO_ACCURACY
# CREATED_ON
# 2019-10-23 05:48:00       3-3 -79.962349  40.468815        EXACT
# 2019-10-23 07:15:00      4-24 -79.982259  40.426606        EXACT
# 2019-10-23 07:33:00       4-5 -79.994152  40.424756  APPROXIMATE
# 2019-10-23 07:34:00       3-7 -79.933371  40.475925        EXACT
# 2019-10-23 07:35:00      2-18 -79.927131  40.441994        EXACT

# %% [markdown]
# ## Grouping time with the `resample` method
#
# * The `resample()` method is like `groupby()` but for time.
# * First you *split* your data into groupings of time
# * Then *apply* an aggregation functions to perform calculations

# %%
# count the number of complaints per month
pgh_311_data.resample("W").size().head()
# Out:
# CREATED_ON
# 2015-02-22    1
# 2015-03-01    0
# 2015-03-08    0
# 2015-03-15    0
# 2015-03-22    0
# Freq: W-SUN, dtype: int64

# %%
# compute the mean of complaints per quarter...note this doesn't make sense, but works anyway
pgh_311_data.resample("Q").mean().head()
# Out:
#               REQUEST_ID    STATUS  COUNCIL_DISTRICT       WARD         TRACT  \
# CREATED_ON
# 2015-03-31    538.000000  1.000000          6.000000  21.000000  4.200398e+10
# 2015-06-30   6143.763130  1.005414          4.974359  16.517505  4.200323e+10
# 2015-09-30  18638.293041  1.028015          4.864908  16.469618  4.200323e+10
# 2015-12-31  32599.676418  1.142104          4.845971  16.144843  4.200323e+10
# 2016-03-31  48803.170285  1.182238          4.763623  16.039700  4.200323e+10
#
#             PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE          X  \
# CREATED_ON
# 2015-03-31               1.000000     21.000000     1.000000 -80.030956
# 2015-06-30               3.075636     16.517505     3.733333 -79.848253
# 2015-09-30               3.113021     16.469618     3.645369 -79.060258
# 2015-12-31               3.082629     16.144843     3.583575 -79.152093
# 2016-03-31               3.144611     16.039700     3.584795 -79.318963
#
#                     Y
# CREATED_ON
# 2015-03-31  40.453466
# 2015-06-30  40.377188
# 2015-09-30  39.978234
# 2015-12-31  40.024438
# 2016-03-31  40.108187

# %% [markdown]
# * Ok, these data are *begging* to be visualized, so I'm going to give you a teaser of next week

# %%
# Tell matplotlib to render plots inline
# %matplotlib inline

# %%
# Create a graph of the monthly complaint counts
pgh_311_data['REQUEST_ID'].resample("M").count().plot();

# %% [markdown]
# Try the code above, but re-sampling based upon different date periods. The strings for specifying an offset are located [here](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases) and below:
#
# |Alias|Description|
# |-----|-----------|
# |B|business day frequency|
# |C|custom business day frequency|
# |D|calendar day frequency|
# |W|weekly frequency|
# |M|month end frequency|
# |SM|semi-month end frequency (15th and end of month)|
# |BM|business month end frequency|
# |CBM|custom business month end frequency|
# |MS|month start frequency|
# |SMS|semi-month start frequency (1st and 15th)|
# |BMS|business month start frequency|
# |CBMS|custom business month start frequency|
# |Q|quarter end frequency|
# |BQ|business quarter end frequency|
# |QS|quarter start frequency|
# |BQS|business quarter start frequency|
# |A, Y|year end frequency|
# |BA, BY|business year end frequency|
# |AS, YS|year start frequency|
# |BAS, BYS|business year start frequency|
# |BH|business hour frequency|
# |H|hourly frequency|
# |T, min|minutely frequency|
# |S|secondly frequency|
# |L, ms|milliseconds|
# |U, us|microseconds|
# |N|nanoseconds|

# %%
# Try a different resampling here

pgh_311_data['REQUEST_ID'].resample("Y").count().plot();

# %%
# Try yet another resampling here

pgh_311_data['REQUEST_ID'].resample("M").size().plot();

# %% [markdown]
# ## Exploring the 311 Data
#
# * Now we can use what we have learned to do some exploratory data analysis on the 311 data
# * First, lets use the `sample()` method to grab 10 random rows so we can get a feel for the data

# %%
# Sample 10 random rows from the dataframe
pgh_311_data.sample(10)
# Out:
#                      REQUEST_ID               REQUEST_TYPE REQUEST_ORIGIN  \
# CREATED_ON
# 2016-10-10 11:23:00    109627.0               Weeds/Debris    Call Center
# 2018-10-01 10:49:00    292190.0      Street Light - Repair        Website
# 2019-02-25 15:31:00    321393.0      Replace/Repair a Sign    Call Center
# 2017-02-07 14:32:00    130558.0  Building Without a Permit  Control Panel
# 2018-12-18 09:56:00    305884.0               Weeds/Debris    Call Center
# 2017-04-21 10:39:00    147128.0             Paving Request   Text Message
# 2016-11-30 11:15:00    118424.0                   Referral    Call Center
# 2017-03-28 15:27:00    141743.0          Refuse Violations   Text Message
# 2018-05-11 12:56:00    247677.0                   Potholes    Call Center
# 2017-05-18 09:19:00    154606.0    Public Works Department        Website
#
#                      STATUS                         DEPARTMENT  \
# CREATED_ON
# 2016-10-10 11:23:00       1  Permits, Licenses and Inspections
# 2018-10-01 10:49:00       1            Allegheny City Electric
# 2019-02-25 15:31:00       1                 DOMI - TrafficShop
# 2017-02-07 14:32:00       1  Permits, Licenses and Inspections
# 2018-12-18 09:56:00       1  Permits, Licenses and Inspections
# 2017-04-21 10:39:00       1                     DOMI - Asphalt
# 2016-11-30 11:15:00       1                                311
# 2017-03-28 15:27:00       1                       DPW - Refuse
# 2018-05-11 12:56:00       1           DPW - Street Maintenance
# 2017-05-18 09:19:00       1               DPW - Administration
#
#                           NEIGHBORHOOD  COUNCIL_DISTRICT  WARD         TRACT  \
# CREATED_ON
# 2016-10-10 11:23:00            Carrick               4.0  29.0  4.200329e+10
# 2018-10-01 10:49:00   Duquesne Heights               2.0  19.0  4.200319e+10
# 2019-02-25 15:31:00  Central Northside               1.0  22.0  4.200322e+10
# 2017-02-07 14:32:00  Central Northside               1.0  22.0  4.200322e+10
# 2018-12-18 09:56:00  South Side Slopes               3.0  16.0  4.200316e+10
# 2017-04-21 10:39:00          Shadyside               8.0   7.0  4.200307e+10
# 2016-11-30 11:15:00                NaN               NaN   NaN           NaN
# 2017-03-28 15:27:00            Windgap               2.0  28.0  4.200356e+10
# 2018-05-11 12:56:00     Homewood North               9.0  13.0  4.200313e+10
# 2017-05-18 09:19:00                NaN               NaN   NaN           NaN
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# CREATED_ON
# 2016-10-10 11:23:00                    3.0          29.0          3.0
# 2018-10-01 10:49:00                    5.0          19.0          3.0
# 2019-02-25 15:31:00                    1.0          22.0          1.0
# 2017-02-07 14:32:00                    1.0          22.0          1.0
# 2018-12-18 09:56:00                    3.0          16.0          3.0
# 2017-04-21 10:39:00                    2.0           7.0          4.0
# 2016-11-30 11:15:00                    NaN           NaN          NaN
# 2017-03-28 15:27:00                    5.0          28.0          6.0
# 2018-05-11 12:56:00                    2.0          13.0          5.0
# 2017-05-18 09:19:00                    NaN           NaN          NaN
#
#                     FIRE_ZONE          X          Y   GEO_ACCURACY
# CREATED_ON
# 2016-10-10 11:23:00      4-23 -79.981083  40.381155          EXACT
# 2018-10-01 10:49:00       4-1 -80.024077  40.436272          EXACT
# 2019-02-25 15:31:00       1-6 -80.005665  40.456871          EXACT
# 2017-02-07 14:32:00      1-21 -80.012612  40.455713    APPROXIMATE
# 2018-12-18 09:56:00      4-22 -79.969478  40.421916          EXACT
# 2017-04-21 10:39:00      3-11 -79.923807  40.456248          EXACT
# 2016-11-30 11:15:00       NaN        NaN        NaN  OUT_OF_BOUNDS
# 2017-03-28 15:27:00      1-16 -80.078069  40.459856    APPROXIMATE
# 2018-05-11 12:56:00      3-17 -79.895470  40.459522          EXACT
# 2017-05-18 09:19:00       NaN        NaN        NaN  OUT_OF_BOUNDS

# %%
# Where are the requests generally coming from?
pgh_311_data['REQUEST_ORIGIN'].value_counts()
# Out:
# Call Center           234269
# Website                72184
# Control Panel          42470
# Report2Gov iOS         13101
# Twitter                 7649
# Report2Gov Android      4641
# Text Message            1452
# Email                    210
# Report2Gov Website        79
# QAlert Mobile iOS          5
# Name: REQUEST_ORIGIN, dtype: int64

# %%
# What neighborhood complains the most
pgh_311_data.groupby('NEIGHBORHOOD').size().sort_values(ascending=False)
# Out:
# NEIGHBORHOOD
# Brookline                    15476
# Carrick                      14562
# Squirrel Hill South          12389
# South Side Slopes            11994
# South Side Flats             11287
# Bloomfield                    9912
# Mount Washington              9800
# Beechview                     9399
# Central Business District     8280
# Shadyside                     7878
# Greenfield                    7645
# Central Lawrenceville         7246
# Hazelwood                     7147
# East Liberty                  6992
# Sheraden                      6365
# Lincoln-Lemington-Belmar      6222
# Squirrel Hill North           6104
# Brighton Heights              5946
# Garfield                      5919
# Knoxville                     5829
# Marshall-Shadeland            5752
# Stanton Heights               5378
# Highland Park                 5349
# Perry North                   5297
# Overbrook                     5294
# Elliott                       5214
# East Allegheny                5121
# Homewood North                4888
# Perry South                   4862
# Central Oakland               4550
#                              ...
# Homewood West                 1480
# Friendship                    1387
# Allegheny Center              1371
# Windgap                       1281
# California-Kirkbride          1234
# Bon Air                       1205
# Mt. Oliver                    1189
# Swisshelm Park                1153
# West End                      1135
# Terrace Village               1117
# Summer Hill                   1104
# North Shore                   1099
# Regent Square                 1097
# Bedford Dwellings              867
# New Homestead                  828
# Allegheny West                 773
# Oakwood                        735
# Esplen                         725
# South Shore                    704
# Chateau                        695
# Fairywood                      671
# Hays                           658
# St. Clair                      523
# Chartiers City                 462
# Ridgemont                      444
# East Carnegie                  358
# Northview Heights              357
# Glen Hazel                     226
# Arlington Heights               79
# Mount Oliver Borough            51
# Length: 91, dtype: int64

# %%
# Note, for just counting the groupby and value_counts are equivalent
# There is more than one way to skin the cat (or panda)
pgh_311_data['NEIGHBORHOOD'].value_counts()
# Out:
# Brookline                    15476
# Carrick                      14562
# Squirrel Hill South          12389
# South Side Slopes            11994
# South Side Flats             11287
# Bloomfield                    9912
# Mount Washington              9800
# Beechview                     9399
# Central Business District     8280
# Shadyside                     7878
# Greenfield                    7645
# Central Lawrenceville         7246
# Hazelwood                     7147
# East Liberty                  6992
# Sheraden                      6365
# Lincoln-Lemington-Belmar      6222
# Squirrel Hill North           6104
# Brighton Heights              5946
# Garfield                      5919
# Knoxville                     5829
# Marshall-Shadeland            5752
# Stanton Heights               5378
# Highland Park                 5349
# Perry North                   5297
# Overbrook                     5294
# Elliott                       5214
# East Allegheny                5121
# Homewood North                4888
# Perry South                   4862
# Central Oakland               4550
#                              ...
# Homewood West                 1480
# Friendship                    1387
# Allegheny Center              1371
# Windgap                       1281
# California-Kirkbride          1234
# Bon Air                       1205
# Mt. Oliver                    1189
# Swisshelm Park                1153
# West End                      1135
# Terrace Village               1117
# Summer Hill                   1104
# North Shore                   1099
# Regent Square                 1097
# Bedford Dwellings              867
# New Homestead                  828
# Allegheny West                 773
# Oakwood                        735
# Esplen                         725
# South Shore                    704
# Chateau                        695
# Fairywood                      671
# Hays                           658
# St. Clair                      523
# Chartiers City                 462
# Ridgemont                      444
# East Carnegie                  358
# Northview Heights              357
# Glen Hazel                     226
# Arlington Heights               79
# Mount Oliver Borough            51
# Name: NEIGHBORHOOD, Length: 91, dtype: int64

# %%
# Count the different types of requests
pgh_311_data.groupby("REQUEST_TYPE").size().sort_values(ascending=False)
# Out:
# REQUEST_TYPE
# Potholes                                           51865
# Weeds/Debris                                       34593
# Building Maintenance                               17968
# Snow/Ice removal                                   12488
# Abandoned Vehicle (parked on street)               10606
# Refuse Violations                                  10266
# Missed Pick Up                                      8672
# Litter                                              8031
# Illegal Parking                                     7457
# Replace/Repair a Sign                               7203
# Street Light - Repair                               6992
# Building Without a Permit                           6608
# City Source (CDBG)                                  6221
# Overgrowth                                          5936
# Paving Request                                      5512
# Pruning (city tree)                                 4830
# Referral                                            4815
# Vacant Building                                     4502
# Rodent control                                      3775
# Sinkhole                                            3596
# Dead Animal                                         3500
# Request New Sign                                    3494
# Catch Basin, Clogged                                3399
# Street Cleaning/Sweeping                            3310
# Illegal Dumping                                     3211
# Leak                                                3099
# Broken Sidewalk                                     2893
# Traffic or Pedestrian Signal, Repair                2792
# Early Set Out                                       2715
# Patrol                                              2691
#                                                    ...
# Maintenance Conditions                                 7
# Payroll Expense Tax                                    7
# Building Benchmark Ordinance                           7
# Improvements                                           7
# Thank you - Finance                                    7
# KNOWLEDGE BASE ARTICLES                                7
# Bus Shelter Relocation Request                         7
# Side Yard Program                                      7
# Schenley Ice Rink                                      6
# Towed Vehicle/Do Not Use                               6
# Demolition - DO NOT USE                                5
# Greenways                                              4
# EMS Billing                                            4
# Catch Basins                                           3
# Billing                                                3
# Hold - 311                                             3
# Homestead Act/Senior Tax Relief                        3
# Permits                                                3
# Bicycle/Pedestrian/Trail - Network Improvements        3
# Bicycle Parking                                        2
# Planning Issues                                        2
# Environmental Services - Refuse Accumulation           2
# EMT                                                    2
# Amenities                                              1
# Commission on Human Relations                          1
# Amusement Tax                                          1
# Benefits                                               1
# Parking Tax                                            1
# Handicapped Parking Sign Request                       1
# Sidewalk (city property)                               1
# Length: 315, dtype: int64

# %% [markdown]
# * This categorical data is far too granular.
# * Fortunately, if we look at the [311 Data](https://data.wprdc.org/dataset/311-data) we can see there is a [311 Issue and Category Codebook](https://data.wprdc.org/dataset/311-data/resource/7794b313-33be-4a8b-bf80-41751a59b84a).
#
# * What we need to do is download the CSV from Google Sheets directly into a Pandas dataframe, which requires some fancy URL-ing

# %%
# I googled "pandas dataframe from google sheets"
# and found a solution on Stackoverflow
# https://stackoverflow.com/a/35246041
issue_category_mapping = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   '1DTDBhwXj1xQG1GCBKPqivlzHQaLh2HLd0SjN1XBPUw0' +
                   '/export?gid=0&format=csv')
issue_category_mapping.head(5)  # Same result as @TomAugspurger
# Out:
#         Category                                    Issue Definition  \
# 0  Accessibility              Americans with Disabilities        NaN
# 1  Accessibility                            City Facility        NaN
# 2  Accessibility                    Handicap Ramp, Repair        NaN
# 3  Accessibility  Handicap Ramp, Request for Installation        NaN
# 4  Accessibility       Sidewalk, Lack of Snow/Ice Removal        NaN
#
#                            Department
# 0        City Planning - Disabilities
# 1                    DPW - Facilities
# 2         DPW - Construction Division
# 3  DPW - Transportation & Engineering
# 4                                 311

# %% [markdown]
# ## Exercise
#
# * We have two dataframes with one shared column. The `REQUEST_TYPE` column in `pgh_311_data` maps to the `Issue` column in `issue_category_mapping`
# * Use the `pd.merge()` function to create a new dataframe that combines the `pgh_311_data` with the `issue_category_mapping` so we can count the number of complaints per Category instead of Request type.
#     * *HINT*: You will need to specify the `left_on` and `right_on` parameters
# * Once you have created a new dataframe, do a `groupby` on the Category column and count the number of complaints
#     * *HINT*: Use the `size()` aggregation function and then `sort_values()` if you want it nicely ordered.

# %%
# Your code here

# %%
# create a new merged dataframe
merged_311_data = pd.merge(pgh_311_data, 
         issue_category_mapping,
         left_on="REQUEST_TYPE",
         right_on="Issue")

merged_311_data.head()
# Out:
#    REQUEST_ID                REQUEST_TYPE REQUEST_ORIGIN  STATUS  \
# 0    203364.0  Street Obstruction/Closure    Call Center       1
# 1    184586.0  Street Obstruction/Closure    Call Center       1
# 2    183065.0  Street Obstruction/Closure    Call Center       1
# 3    181351.0  Street Obstruction/Closure    Call Center       1
# 4    177411.0  Street Obstruction/Closure    Call Center       1
#
#        DEPARTMENT         NEIGHBORHOOD  COUNCIL_DISTRICT  WARD         TRACT  \
# 0  DOMI - Permits    Central Northside               1.0  22.0  4.200322e+10
# 1  DOMI - Permits  Lower Lawrenceville               7.0   6.0  4.200309e+10
# 2  DOMI - Permits              Windgap               2.0  20.0  4.200356e+10
# 3  DOMI - Permits              Carrick               4.0  29.0  4.200329e+10
# 4  DOMI - Permits        North Oakland               8.0   5.0  4.200356e+10
#
#    PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE FIRE_ZONE          X  \
# 0                    1.0          22.0          1.0       1-7 -80.016716
# 1                    2.0           6.0          2.0       3-3 -79.966906
# 2                    5.0          20.0          6.0      1-16 -80.073213
# 3                    3.0          29.0          3.0      4-23 -79.981714
# 4                    3.0           5.0          4.0      2-23 -79.952022
#
#            Y GEO_ACCURACY            Category                       Issue  \
# 0  40.454144        EXACT  Road/Street Issues  Street Obstruction/Closure
# 1  40.471717        EXACT  Road/Street Issues  Street Obstruction/Closure
# 2  40.457633        EXACT  Road/Street Issues  Street Obstruction/Closure
# 3  40.381741        EXACT  Road/Street Issues  Street Obstruction/Closure
# 4  40.451890        EXACT  Road/Street Issues  Street Obstruction/Closure
#
#   Definition     Department
# 0        NaN  DPW - Permits
# 1        NaN  DPW - Permits
# 2        NaN  DPW - Permits
# 3        NaN  DPW - Permits
# 4        NaN  DPW - Permits

# %%
# get rid of redundant columns
merged_311_data.drop(['Definition','Department', 'Issue'], 
                     axis=1, 
                     inplace=True)
merged_311_data.head()
# Out:
#    REQUEST_ID                REQUEST_TYPE REQUEST_ORIGIN  STATUS  \
# 0    203364.0  Street Obstruction/Closure    Call Center       1
# 1    184586.0  Street Obstruction/Closure    Call Center       1
# 2    183065.0  Street Obstruction/Closure    Call Center       1
# 3    181351.0  Street Obstruction/Closure    Call Center       1
# 4    177411.0  Street Obstruction/Closure    Call Center       1
#
#        DEPARTMENT         NEIGHBORHOOD  COUNCIL_DISTRICT  WARD         TRACT  \
# 0  DOMI - Permits    Central Northside               1.0  22.0  4.200322e+10
# 1  DOMI - Permits  Lower Lawrenceville               7.0   6.0  4.200309e+10
# 2  DOMI - Permits              Windgap               2.0  20.0  4.200356e+10
# 3  DOMI - Permits              Carrick               4.0  29.0  4.200329e+10
# 4  DOMI - Permits        North Oakland               8.0   5.0  4.200356e+10
#
#    PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE FIRE_ZONE          X  \
# 0                    1.0          22.0          1.0       1-7 -80.016716
# 1                    2.0           6.0          2.0       3-3 -79.966906
# 2                    5.0          20.0          6.0      1-16 -80.073213
# 3                    3.0          29.0          3.0      4-23 -79.981714
# 4                    3.0           5.0          4.0      2-23 -79.952022
#
#            Y GEO_ACCURACY            Category
# 0  40.454144        EXACT  Road/Street Issues
# 1  40.471717        EXACT  Road/Street Issues
# 2  40.457633        EXACT  Road/Street Issues
# 3  40.381741        EXACT  Road/Street Issues
# 4  40.451890        EXACT  Road/Street Issues

# %%
# Group by the Category and count the size of each group then sort by 
merged_311_data.groupby("Category").size().sort_values(ascending=False)
# Out:
# Category
# Road/Street Issues                                 112489
# Neighborhood Issues                                 46547
# Garbage and Litter Issues                           29627
# Building Maintenance                                25902
# Parking                                             19920
# Parks Issues                                        17218
# In database, but not on 311 Web Submission Form     13631
# Construction Issues                                 12847
# Tree Issues                                         12338
# Public Safety                                       11627
# Animal Issues                                       10577
# Utility Issues                                      10575
# Street Light                                         7460
# Business Issues                                      5361
# City Facilities and Infrastructure                   4410
# Ask Us/General FAQs                                  2819
# Traffic and Street Sign Issues                       2792
# Graffiti Issues                                      2618
# Permits                                              2483
# Accessibility                                        1913
# Weeds/Debris                                         1534
# Pedestrian/Bicycle Concerns                           705
# Personnel (City)                                      566
# Taxes                                                 156
# Communications (Cable, Website)                       138
# dtype: int64

# %% [markdown]
# * Where are are most 311 from the Greenfield neighborhood originating?

# %%
# Select only rows where NEIGHBORHOOD equals "Greenfield" and then count how many complaints came from each source
query_mask = merged_311_data['NEIGHBORHOOD'] == 'Greenfield'
merged_311_data[query_mask].groupby('REQUEST_ORIGIN').size().sort_values(ascending=False)
# Out:
# REQUEST_ORIGIN
# Call Center           4864
# Website               1583
# Control Panel          506
# Report2Gov iOS         217
# Twitter                145
# Text Message            64
# Report2Gov Android      43
# Email                    2
# Report2Gov Website       1
# dtype: int64

# %%
query_mask = merged_311_data['REQUEST_TYPE'] == '*Thank You*'
merged_311_data[query_mask].groupby('REQUEST_TYPE').size().sort_values(ascending=False)
# Out:
# Series([], dtype: int64)
